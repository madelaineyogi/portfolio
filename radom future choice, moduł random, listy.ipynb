# %% [raw]
# import sys, random
#
# print('Hi, how u doin? Let\' play somethin pretty fun. It\'s time to stay kind of wizzard when you see the star\'s future')
#
# women = ['Ariana Grande', 'Jessica Alba', 'Angelina Jolie', 'Natalie Portman', 'Taylor Swift']
#
# men = ['Brad Pitt', 'Ashton Kutcher', 'Ryan Gosling', 'Kuba Wojewódzki', 'Tom Crusie']
#
# woman = print(random.choice(women))

# %%
import sys, random

print('Hi, how u doin? Let\' play somethin pretty fun. It\'s time to stay kind of wizzard when you see the star\'s future')

women = ['Ariana Grande', 'Jessica Alba', 'Angelina Jolie', 'Natalie Portman', 'Taylor Swift']

men = ['Brad Pitt', 'Ashton Kutcher', 'Ryan Gosling', 'Kuba Wojewódzki', 'Tom Crusie']

future = [' a big love', ' a divorce', 'an affair', ' a marriage']

woman = random.choice(women)
man = random.choice(men)

new_couple = print(woman, ' and ', man, ' will have...', ' ', random.choice(future), '!')
# Out:
# Hi, how u doin? Let' play somethin pretty fun. It's time to stay kind of wizzard when you see the star's future
# Jessica Alba  and  Tom Crusie  will have...    a divorce !
